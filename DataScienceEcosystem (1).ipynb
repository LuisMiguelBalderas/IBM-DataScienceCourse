# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem
# ![2-title.png](attachment:c4b50758-73e4-4514-8ddc-37f2c15690b6.png)

# %% [markdown]
# #### In this notebook, Data Science Tools and Ecosystem are summarized.
# ![3-intro.png](attachment:72c3a72b-b6ce-44de-90b4-c1bb87b3bb72.png)

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - List popular libraries for Data Science
# - List popular tools for Data Science
# - Evaluate code examples
# ![10-objectives.png](attachment:e8858167-6b3b-4949-bb8f-199f72eb0ec3.png)

# %% [markdown]
# ###### Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# ![4-dslanguage.png](attachment:0ec3f0c0-bfff-46bf-a7c0-4f7edfa487a2.png)

# %% [markdown]
# ###### Some of the commonly used libraries used by Data Scientists include:
# 1. pandas
# 2. seaborn
# 3. skicitlearn
# ![5-dslibraries.png](attachment:0375bca2-b92d-4b19-b66b-264d16e711ca.png)

# %% [markdown]
# |Data Science Tools|
# |------------------|
# |Python|
# |Jupyter Notebooks|
# |Pandas|
# ![6-dstools.png](attachment:32edce99-3e7a-417e-aedc-a79bf459ef17.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python
# ![7-introarithmetic.png](attachment:75ccb1c3-31b2-4e4c-adf8-9f383c5c0126.png)

# %%
(3*4)+5
# This a simple arithmetic expression to mutiply then add integers
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:f973866e-de77-4f13-ba41-6609ba11c1d1.png)

# %%
200/60
# This will convert 200 minutes to hours by diving by 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:8b59663d-f9f3-4ef5-82e7-14b0b6e0b997.png)

# %% [markdown]
# ## Author
# Luis Miguel Balderas
# ![11-authordetails.png](attachment:9f409500-406d-48f4-9558-824df109773b.png)
